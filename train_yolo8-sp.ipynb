# %%
from ultralytics import YOLO
model = YOLO("ultralytics/cfg/models/v8/yolov8n-sp.yaml")
model.train(data="broiler_segmentation-1/data.yaml", epochs=100, imgsz=640, batch=4, optimizer = "SGD", device="mps",)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 from ultralytics import YOLO
# ----> 2 model = YOLO("ultralytics/cfg/models/v8/yolov8n-sp.yaml")
#       3 model.train(data="broiler_segmentation-1/data.yaml", epochs=100, imgsz=640, batch=4, optimizer = "SGD", device="mps",)
#
# File ~/Documents/GitHub/ultralytics2/ultralytics/models/yolo/model.py:23, in YOLO.__init__(self, model, task, verbose)
#      20     self.__dict__ = new_instance.__dict__
#      21 else:
#      22     # Continue with default YOLO initialization
# ---> 23     super().__init__(model=model, task=task, verbose=verbose)
#
# File ~/Documents/GitHub/ultralytics2/ultralytics/engine/model.py:146, in Model.__init__(self, model, task, verbose)
#     144 __import__("os").environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"  # to avoid deterministic warnings
# ...
