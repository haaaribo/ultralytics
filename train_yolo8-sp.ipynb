# %%
from ultralytics import YOLO
model = YOLO("ultralytics/cfg/models/v8/yolov8n-sp.yaml")
model.train(data="broiler_segmentation-1/data.yaml", epochs=100, imgsz=640, batch=4, optimizer = "SGD", device="mps",)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 2
#       1 from ultralytics import YOLO
# ----> 2 model = YOLO("/Users/yusangmin/Downloads/ultralytics-main/ultralytics/cfg/models/v8/yolov8n-sp.yaml")
#       3 model.train(data="/Users/yusangmin/Downloads/ultralytics-main/broiler_segmentation-1/data.yaml", epochs=100, imgsz=640, batch=4, optimizer = "SGD", device="mps",)
#
# File ~/Downloads/ultralytics-main/ultralytics/models/yolo/model.py:79, in YOLO.__init__(self, model, task, verbose)
#      76     self.__dict__ = new_instance.__dict__
#      77 else:
#      78     # Continue with default YOLO initialization
# ---> 79     super().__init__(model=model, task=task, verbose=verbose)
#      80     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      81         from ultralytics import RTDETR
#
# File ~/Downloads/ultralytics-main/ultralytics/engine/model.py:149, in Model.__init__(self, model, task, verbose)
#     147 __import__("os").environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"  # to avoid deterministic warnings
#     148 if str(model).endswith((".yaml", ".yml")):
# --> 149     self._new(model, task=task, verbose=verbose)
#     150 else:
#     151     self._load(model, task=task)
#
# File ~/Downloads/ultralytics-main/ultralytics/engine/model.py:261, in Model._new(self, cfg, task, model, verbose)
#     259 self.cfg = cfg
#     260 self.task = task or guess_model_task(cfg_dict)
# --> 261 self.model = (model or self._smart_load("model"))(cfg_dict, verbose=verbose and RANK == -1)  # build model
#     262 self.overrides["model"] = self.cfg
#     263 self.overrides["task"] = self.task
#
# File ~/Downloads/ultralytics-main/ultralytics/nn/tasks.py:559, in SegmentationModel.__init__(self, cfg, ch, nc, verbose)
#     549 def __init__(self, cfg="yolo11n-seg.yaml", ch=3, nc=None, verbose=True):
#     550     """
#     551     Initialize Ultralytics YOLO segmentation model with given config and parameters.
#     552
#    (...)
#     557         verbose (bool): Whether to display model information.
#     558     """
# --> 559     super().__init__(cfg=cfg, ch=ch, nc=nc, verbose=verbose)
#
# File ~/Downloads/ultralytics-main/ultralytics/nn/tasks.py:397, in DetectionModel.__init__(self, cfg, ch, nc, verbose)
#     395     LOGGER.info(f"Overriding model.yaml nc={self.yaml['nc']} with nc={nc}")
#     396     self.yaml["nc"] = nc  # override YAML value
# --> 397 self.model, self.save = parse_model(deepcopy(self.yaml), ch=ch, verbose=verbose)  # model, savelist
#     398 self.names = {i: f"{i}" for i in range(self.yaml["nc"])}  # default names dict
#     399 self.inplace = self.yaml.get("inplace", True)
#
# File ~/Downloads/ultralytics-main/ultralytics/nn/tasks.py:1663, in parse_model(d, ch, verbose)
#    1638 repeat_modules = frozenset(  # modules with 'repeat' arguments
#    1639     {
#    1640         BottleneckCSP,
#    (...)
#    1655     }
#    1656 )
#    1657 for i, (f, n, m, args) in enumerate(d["backbone"] + d["head"]):  # from, number, module, args
#    1658     m = (
#    1659         getattr(torch.nn, m[3:])
#    1660         if "nn." in m
#    1661         else getattr(__import__("torchvision").ops, m[16:])
#    1662         if "torchvision.ops." in m
# -> 1663         else globals()[m]
#    1664     )  # get module
#    1665     for j, a in enumerate(args):
#    1666         if isinstance(a, str):
#
# KeyError: 'C2f_PPA'
